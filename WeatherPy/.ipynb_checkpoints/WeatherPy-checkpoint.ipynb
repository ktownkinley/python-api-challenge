# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
import calendar

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}{city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = time.gmtime(city_weather["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# 0 pariaman
# Processing Record 1 of Set 1 | pariaman
# 1 mossel bay
# Processing Record 2 of Set 1 | mossel bay
# 2 pizarro
# Processing Record 3 of Set 1 | pizarro
# 3 mhamid
# Processing Record 4 of Set 1 | mhamid
# 4 vernon
# Processing Record 5 of Set 1 | vernon
# 5 blackmans bay
# Processing Record 6 of Set 1 | blackmans bay
# 6 edinburgh of the seven seas
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# 7 zhezqazghan
# Processing Record 8 of Set 1 | zhezqazghan
# 8 yemva
# Processing Record 9 of Set 1 | yemva
# 9 isangel
# Processing Record 10 of Set 1 | isangel
# 10 belozersk
# Processing Record 11 of Set 1 | belozersk
# 11 talnakh
# Processing Record 12 of Set 1 | talnakh
# 12 qarazhal
# Processing Record 13 of Set 1 | qarazhal
# 13 longyearbyen
# Processing Record 14 of Set 1 | longyearbyen
# 14 el porvenir
# Processing Record 15 of Set 1 | el porvenir
# 15 grytviken
# ...

# %%
for city in city_data:
    city["Max Temp"] = city["Max Temp"] - 273.15

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    pariaman  -0.6190  100.1200     31.03        76          85        2.00
# 1  mossel bay -34.1831   22.1460     17.96        72          23        7.70
# 2     pizarro   4.9533  -77.3660     25.16        90          94        1.65
# 3      mhamid  29.8200   -5.7200     17.57        32           0        1.36
# 4      vernon  50.2581 -119.2691     15.20        51         100        1.03
#
#   Country        Date
# 0      ID  1712032883
# 1      ZA  1712032884
# 2      CO  1712032884
# 3      MA  1712032885
# 4      CA  1712032886

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          pariaman  -0.6190  100.1200     31.03        76          85
# 1        mossel bay -34.1831   22.1460     17.96        72          23
# 2           pizarro   4.9533  -77.3660     25.16        90          94
# 3            mhamid  29.8200   -5.7200     17.57        32           0
# 4            vernon  50.2581 -119.2691     15.20        51         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.00      ID  1712032883
# 1              7.70      ZA  1712032884
# 2              1.65      CO  1712032884
# 3              1.36      MA  1712032885
# 4              1.03      CA  1712032886

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Temperature (2024-4-1)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2024-4-1)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2024-4-1)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2024-4-1)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x, y, xlab, ylab, ann_spot):
    slope, int, rval, pval, stderr = linregress(x, y=y)
    fit = slope * x + int
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(int,2))
    print(f"The r-value is: {rval**2}")
    plt.scatter(x, y)
    plt.plot(x, fit, "-", color="red")
    plt.annotate(line_eq,ann_spot,fontsize=15,color="red")
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.show()
    return slope, int, rval, pval, stderr

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2            pizarro   4.9533  -77.3660     25.16        90          94
# 3             mhamid  29.8200   -5.7200     17.57        32           0
# 4             vernon  50.2581 -119.2691     15.20        51         100
# 7        zhezqazghan  47.7833   67.7667      6.32        61           0
# 8              yemva  62.5900   50.8594      3.56       100         100
#
#          Wind Speed Country        Date
# City_ID
# 2              1.65      CO  1712032884
# 3              1.36      MA  1712032885
# 4              1.03      CA  1712032886
# 7              3.00      KZ  1712032887
# 8              4.22      RU  1712032661

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           pariaman  -0.6190  100.1200     31.03        76
# 1                         mossel bay -34.1831   22.1460     17.96        72
# 5                      blackmans bay -43.0167  147.3167     14.07        95
# 6        edinburgh of the seven seas -37.0676  -12.3116     18.75        96
# 9                            isangel -19.5500  169.2667     30.06        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                85        2.00      ID  1712032883
# 1                23        7.70      ZA  1712032884
# 5               100        0.45      AU  1712032837
# 6                66        8.43      SH  1712032887
# 9                75        1.03      VU  1712032889

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temperature", (10,-15))
# Out:
# The r-value is: 0.8128655386765684
# (-0.5799481671203982,
#  35.10852577024098,
#  -0.9015905604411397,
#  9.610526551068878e-149,
#  0.013861307141024976)

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Max Temperature", (-55,35))
# Out:
# The r-value is: 0.5523577129333844
# (0.36558784089686475,
#  29.905433805235525,
#  0.7432077185641874,
#  1.3584253288562918e-33,
#  0.024395593642342745)

# %% [markdown]
# **Discussion about the linear relationship:** There is a clear linear relationship between latitude and temperature. As seen in the charts, a latitude of 0 generally represents the highest maximum temperatures, with the max temperature generally dropping as you deviate further from the equator, with a few outliers here and there. In the northern hemisphere, the slope is greater than the southern, which may be caused by the northern hemisphere just coming out of winter. The charts also show that the northern hemisphere has a greater r-value, which shows that the northern hemisphere is greater correlated with the hypothesis that as you travel further from the equator, the more reliably the temperature changes

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity", (45, 15))
# Out:
# The r-value is: 0.04673716452088394
# (0.2552023522723839,
#  58.508600651587955,
#  0.21618779919524583,
#  1.1373614918427819e-05,
#  0.05741261131207448)

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity", (-50,20))
# Out:
# The r-value is: 0.04678525139069946
# (0.25377446989734687,
#  82.94216744067477,
#  0.21629898610649903,
#  0.003187845185004242,
#  0.08490888311420526)

# %% [markdown]
# **Discussion about the linear relationship:** As shown by the charts and the r-value, the correlation here is very loose and not statistically significant. It would appear that there is a slight correlation between traveling north and seeing a rise in humidity but as shown by the slope (being small), it is not a very large change

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", (45, 15))
# Out:
# The r-value is: 0.03498232882559083
# (0.37853271564264357,
#  44.18754358534654,
#  0.18703563517573552,
#  0.0001531863293673812,
#  0.09903624637673729)

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", (-22,20))
# Out:
# The r-value is: 0.08870318135298479
# (0.7442428585539401,
#  80.88417682247028,
#  0.29783079315776734,
#  4.025464274116254e-05,
#  0.17682322655784888)

# %% [markdown]
# **Discussion about the linear relationship:** Although the linear regression line would appear to show a correlation, the r-value is extrememly small and by looking at the chart, it is hard to come to the conclusion that there is a correlation between latitude and cloudiness. For any conclusive analysis of this data, the same regression would have to be done over a long period to establish if there is a distinctive trend

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", (0, 13))
# Out:
# The r-value is: 0.017537067174726362
# (0.01730525038608633,
#  3.109005565468424,
#  0.1324275921956084,
#  0.007617279213027513,
#  0.006452157624246406)

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", (-52, 10))
# Out:
# The r-value is: 0.08392652349440069
# (-0.05349221520031737,
#  2.272113833409855,
#  -0.28970074817715036,
#  6.641155050084868e-05,
#  0.013099973792324093)

# %% [markdown]
# **Discussion about the linear relationship:** Once again, the r-value is extremely low, and although the correlation seems to invert at the equator, the correlation is not statistically significant
